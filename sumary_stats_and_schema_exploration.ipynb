# %% [markdown]
# # Notebook Author:
# ### Brandon Salter

# %%
# link to data: https://drive.google.com/file/d/1KErBeVoLADCa16ck7ReCMkfiRF4Ly_Lp/view?usp=sharing

# %% [markdown]
# # Dependencies

# %%
import json 
import pandas as pd
from pprint import pprint

# %% [markdown]
# note to self: https://stackoverflow.com/questions/41274007/anaconda-export-environment-file

# %% [markdown]
# # Initial Exploration and Summary Stats

# %%
# this code block allows you to inspect 2 tweets and 2 retweets in the dataset
# it also saves all the unique tweets/retweets in the dictionary tweets
# this code will help you to understand the data
# feel free to print out more fields

lines=0
num_tweets=0
num_retweets=0
print_tweet = 0
print_retweet = 0
tweets = {}
retweets = {}
users = {}

#insert path and replace name of the file below as needed
with open("corona-out-3.json", "r") as f1:
    for line in f1:
        try:
            data = json.loads(line)
            lines = lines + 1
            if ( data['text'].startswith('RT') ):
                num_retweets += 1
                #print out some fields of one retweet 
                #note that you should look at other fields too
                if (print_retweet < 1):
                    print_retweet += 1
                    print('RETWEET\n','id--',data['id'],'text--',data['text'],'\n')
                    
                    print('User-- ',data['user'],'\n')
                  
                    print('retweetstatus--',data['retweeted_status'],'\n')
                  

            else:
                num_tweets += 1
                #print out some fields of one tweet 
                #note that you should look at other fields too
                if (print_tweet < 1):
                    print_tweet += 1
                    print('TWEET\n','id--',data['id'],'text--',data['text'],'\n')
                    print('User-- ',data['user'],'\n')
                    


            if (data['id_str'] not in tweets) and (data['id_str'] not in retweets):
                if ( data['text'].startswith('RT') ):
                    retweets[data['id_str']] = data
                else:
                    tweets[data['id_str']] = data
            
            if (data['user']['id_str'] not in users):
                users[data['user']['id_str']] = data['user']['screen_name']
            
        except:
            # if there is an error loading the json of the tweet, skip
            continue

# Summary Stats
df = pd.DataFrame.from_dict({'Lines': [lines],
                             'Tweets': [num_tweets],
                             'Retweets': [num_retweets],
                             'Users': [len(users.keys())],
                             'Unique Tweets/Retweets':[len(tweets.keys())+len(retweets.keys())]})
display(df)
# Out:
# TWEET
#  id-- 1254022770679320576 text-- É isto, ou vou morrer sem ar ou com o corona https://t.co/O0Y7B3Koj4
#
# ...

# %%
print(lines - len(tweets) - len(retweets)) # => overlapping id_str's ??
print(lines - (len(tweets.keys())+len(retweets.keys())))
# Out:
# 22
# 22

# %% [markdown]
# # Further Schema Exploration

# %%
pprint(tweets[next(iter(tweets))])
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Apr 25 12:21:41 +0000 2020',
#  'display_text_range': [0, 44],
#  'entities': {'hashtags': [],
#               'media': [{'display_url': 'pic.twitter.com/O0Y7B3Koj4',
#                          'expanded_url': 'https://twitter.com/B_King69/status/1254022770679320576/photo/1',
#                          'id': 1254022759824461824,
#                          'id_str': '1254022759824461824',
#                          'indices': [45, 68],
#                          'media_url': 'http://pbs.twimg.com/media/EWcvDlOXkAAznwM.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/EWcvDlOXkAAznwM.jpg',
#                          'sizes': {'large': {'h': 2048,
#                                              'resize': 'fit',
#                                              'w': 1038},
#                                    'medium': {'h': 1200,
# ...

# %%
pprint(retweets[next(iter(retweets))])
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Apr 25 12:21:42 +0000 2020',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 207809313,
#                                  'id_str': '207809313',
#                                  'indices': [3, 13],
#                                  'name': 'BJP',
#                                  'screen_name': 'BJP4India'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1254022772558368768,
#  'id_str': '1254022772558368768',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
# ...

# %%
pprint(data['user'])
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Thu Nov 23 16:29:56 +0000 2017',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': None,
#  'favourites_count': 68,
#  'follow_request_sent': None,
#  'followers_count': 1,
#  'following': None,
#  'friends_count': 44,
#  'geo_enabled': False,
#  'id': 933734367679123456,
#  'id_str': '933734367679123456',
#  'is_translator': False,
#  'lang': None,
#  'listed_count': 0,
#  'location': None,
#  'name': 'Jacob',
#  'notifications': None,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': '',
#  'profile_background_image_url_https': '',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/933736718141968384/uxpf4THz_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/933736718141968384/uxpf4THz_normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
# ...

# %%
# print the last data item
pprint(data)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Apr 25 14:48:38 +0000 2020',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 19236255,
#                                  'id_str': '19236255',
#                                  'indices': [3, 18],
#                                  'name': 'Anders Lindberg',
#                                  'screen_name': 'anderslindberg'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1254059752201519104,
#  'id_str': '1254059752201519104',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'sv',
#  'place': None,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
# ...

# %%
# Tweet Keys:

### For Retweets ###
print(data['retweeted_status']['id_str'])
print(data['retweeted_status']['user']['id_str'])
print()
####################

print(data['created_at'])
print(data['entities']['hashtags'])
print(data['id_str'])
print(data['text'])
print(data['favorite_count'])
print(data['lang'])
print(data['place'])
print(data['quote_count'])
print(data['reply_count'])
print(data['retweet_count'])
print(data['user']['favourites_count'])
print(data['user']['followers_count'])
print(data['user']['friends_count'])
print(data['user']['id_str'])
print(data['user']['location'])
print(data['user']['name'])
print(data['user']['screen_name'])
print(data['user']['statuses_count'])
print(data['user']['verified'])
# Out:
# 1253966779900137472
# 19236255
#
# Sat Apr 25 14:48:38 +0000 2020
# []
# 1254059752201519104
# RT @anderslindberg: För att förstå vad Anders Tegnell menar med ”ett snabbare förlopp” krävs att man förstår svaret på en gåta. Hur många g…
# 0
# sv
# None
# 0
# 0
# 0
# 68
# 1
# 44
# 933734367679123456
# None
# Jacob
# lundgreenjacob
# 12
# False

# %%
# User Keys

print(data['user']['created_at'])
print(data['user']['description'])
print(data['user']['favourites_count'])
print(data['user']['followers_count'])
print(data['user']['following'])
print(data['user']['friends_count'])
print(data['user']['id_str'])
print(data['user']['lang'])
print(data['user']['location'])
print(data['user']['name'])
print(data['user']['screen_name'])
print(data['user']['statuses_count'])
print(data['user']['verified'])
# Out:
# Thu Nov 23 16:29:56 +0000 2017
# None
# 68
# 1
# None
# 44
# 933734367679123456
# None
# None
# Jacob
# lundgreenjacob
# 12
# False

# %%
del tweets
del retweets
del users
