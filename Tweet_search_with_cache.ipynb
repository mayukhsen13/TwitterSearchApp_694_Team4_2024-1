# %% [markdown]
# #CODE AUTHOR-
# SEARCH QUERIES- MAX JACOBS
# CACHE- DIVYA SHAH

# %% [markdown]
# # Search function

# %%
import os

# Install db-dtypes package
os.system('pip install db-dtypes')
# Out:
# 0

# %% [markdown]
# ### Run cells below then run search()

# %%
import warnings
from google.cloud import bigquery
from google.oauth2 import service_account
from IPython.display import clear_output
import subprocess
subprocess.run(["pip", "install", "db-dtypes"])
# Out:
# CompletedProcess(args=['pip', 'install', 'db-dtypes'], returncode=0)

# %%
credentials = service_account.Credentials.from_service_account_info({
  "type": "service_account",
  "project_id": "msds-417117",
  "private_key_id": "b6e22a6ede54ccdd4765660a5ad6bd5edd834fdf",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "python@msds-417117.iam.gserviceaccount.com",
  "client_id": "105118685802142068024",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/python%40msds-417117.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}
)

project_id = 'msds-417117'
client = bigquery.Client(credentials= credentials,project=project_id)

# %% [markdown]
# ## Query templates

# %% [markdown]
# ## Tweet containing a string

# %%
def string_search(words, choice_and_or, date_and_or, range_choice, time_and_or, time_choice):
    
    if choice_and_or == "AND":
        text_where_clause = "AND ".join([f"text LIKE '% {word} %'" for word in words])
    elif choice_and_or == "OR":
        text_where_clause = "OR ".join([f"text LIKE '% {word} %'" for word in words])
    else: 
        text_where_clause = (f"text LIKE '% {words} %'")
        
    if date_and_or == "AND RANGE" or date_and_or == "SINGLE RANGE":
        date_where_clause = "AND ".join([f"DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in range_choice])
    elif date_and_or == "OR RANGE":
        date_where_clause = "OR ".join([f"DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in range_choice])
    else: 
        date_where_clause = f"DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {range_choice}"

    if time_and_or == "AND RANGE" or time_and_or == "SINGLE RANGE":
        time_where_clause = "AND ".join([f"TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in time_choice])
    elif time_and_or == "OR RANGE":
        time_where_clause = "OR ".join([f"TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in time_choice])
    else: 
        time_where_clause = f"TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {time_choice}"


    where_clauses = [text_where_clause]

    if range_choice:
        where_clauses.append(date_where_clause)

    if time_choice:
        where_clauses.append(time_where_clause)

    if len(where_clauses) > 1:
        where_clause = " AND ".join(where_clauses)
    else:
        where_clause = text_where_clause


    sql_query = f"""
    SELECT 
        text, 
        retweet_count, 
        DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS date,
        TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS time,
        id_str_user, 
        id_str_tweet
    FROM `msds-417117.Tweets.Tweets`
    WHERE {where_clause}
    ORDER BY retweet_count DESC
    """

    query = client.query(sql_query)
    result = query.to_dataframe()

    return result

# %% [markdown]
# ## Tweet containing a hashtag

# %%
def hashtag_search(hashtags, choice_and_or, date_and_or, range_choice, time_and_or, time_choice):
    
    if choice_and_or == "AND":
        hashtag_where_clause = "AND ".join([f"text LIKE '% {hashtag} %'" for hashtag in hashtags])
    elif choice_and_or == "OR":
        hashtag_where_clause = "OR ".join([f"text LIKE '% {hashtag} %'" for hashtag in hashtags])
    else: 
        hashtag_where_clause = (f"text LIKE '% {hashtags} %'")
        
    if date_and_or == "AND RANGE" or date_and_or == "SINGLE RANGE":
        date_where_clause = "AND ".join([f"DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in range_choice])
    elif date_and_or == "OR RANGE":
        date_where_clause = "OR ".join([f"DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in range_choice])
    else: 
        date_where_clause = f"DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {range_choice}"

    if time_and_or == "AND RANGE" or time_and_or == "SINGLE RANGE":
        time_where_clause = "AND ".join([f"TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in time_choice])
    elif time_and_or == "OR RANGE":
        time_where_clause = "OR ".join([f"TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in time_choice])
    else: 
        time_where_clause = f"TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {time_choice}"


    where_clauses = [hashtag_where_clause]

    if range_choice:
        where_clauses.append(date_where_clause)

    if time_choice:
        where_clauses.append(time_where_clause)

    if len(where_clauses) > 1:
        where_clause = " AND ".join(where_clauses)
    else:
        where_clause = hashtag_where_clause


    sql_query = f"""
    SELECT 
        text, 
        retweet_count, 
        DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS date,
        TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS time,
        id_str_user, 
        id_str_tweet
    FROM `msds-417117.Tweets.Tweets`
    WHERE {where_clause}
    ORDER BY retweet_count DESC
    """

    query = client.query(sql_query)
    result = query.to_dataframe()

    return result

# %% [markdown]
# ## Tweet by number of retweets

# %%
def retweet_search(retweets, choice_and_or, date_and_or, range_choice, time_and_or, time_choice):
    
    if choice_and_or == "AND":
        retweet_where_clause = "AND ".join([f"retweet_count {retweet} " for retweet in retweets])
    elif choice_and_or == "OR":
        retweet_where_clause = "OR ".join([f"retweet_count {retweet}" for retweet in retweets])
    else: 
        retweet_where_clause = (f"retweet_count {retweets}")
        
    if date_and_or == "AND RANGE" or date_and_or == "SINGLE RANGE":
        date_where_clause = "AND ".join([f"DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in range_choice])
    elif date_and_or == "OR RANGE":
        date_where_clause = "OR ".join([f"DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in range_choice])
    else: 
        date_where_clause = f"DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {range_choice}"

    if time_and_or == "AND RANGE" or time_and_or == "SINGLE RANGE":
        time_where_clause = "AND ".join([f"TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in time_choice])
    elif time_and_or == "OR RANGE":
        time_where_clause = "OR ".join([f"TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {condition}" for condition in time_choice])
    else: 
        time_where_clause = f"TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) {time_choice}"


    where_clauses = [retweet_where_clause]

    if range_choice:
        where_clauses.append(date_where_clause)

    if time_choice:
        where_clauses.append(time_where_clause)

    if len(where_clauses) > 1:
        where_clause = " AND ".join(where_clauses)
    else:
        where_clause = retweet_where_clause


    sql_query = f"""
    SELECT 
        text, 
        retweet_count, 
        DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS date,
        TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS time,
        id_str_user, 
        id_str_tweet
    FROM `msds-417117.Tweets.Tweets`
    WHERE {where_clause}
    ORDER BY retweet_count DESC
    """

    query = client.query(sql_query)
    result = query.to_dataframe()

    return result

# %% [markdown]
# # Start search function

# %%
def start_search():
    choice = input('''Which metric would you like to search? Input the number corresponding to your choice.
    1 -> Search by word in tweet
    2 -> Search by hashtag in tweet
    3 -> Search by number of retweets
    4 -> RESTART
    ''' + "\n")
    
    if choice == "4" or choice not in ("1", "2", "3"):
        search()
    
    date_and_or = input("\n" + '''Would you like to provide a date range to search? Type 'AND RANGE', 'OR RANGE', 'SINGLE RANGE', or 'NO'.
    ''' + "\n")
    
    if date_and_or == "AND RANGE" or date_and_or == "OR RANGE":
        range_input = input("\n" + '''Enter your conditions on date in exact format without brackets as [ {operator} 'YYYY-MM-DD' ]. 
        Separated by commas, use exactly the symbols: = , < , > , >= , <=
        Example: [ < '2020-04-25', > '2020-03-07' ]\n''' + "\n")
        range_choice = [condition.strip() for condition in range_input.split(',')]
    elif date_and_or == "SINGLE RANGE":
        range_input = input("\n" + '''Enter your condition on date in exact format without brackets as [ {operator} 'YYYY-MM-DD' ]. 
        Use exactly the symbols: = , < , > , >= , <=
        Example: [ < '2020-04-25' ]\n''' + "\n")
        range_choice = [range_input]
    else:
        range_choice = ''
        
    time_and_or = input("\n" + '''Would you like to provide a time range to search? Type 'AND RANGE', 'OR RANGE', 'SINGLE RANGE', or 'NO'.
    ''' + "\n")
        
    if time_and_or == "AND RANGE" or time_and_or == "OR RANGE":
        time_input = input("\n" + '''Enter your conditions on time in exact format without brackets as [ {operator} '24HR:MIN:SEC' ]. 
        Separated by commas, use exactly the symbols: = , < , > , >= , <=
        Example: [ < '13:00:00', > '12:40:00' ]\n''' + "\n")
        time_choice = [condition.strip() for condition in time_input.split(',')]
    elif time_and_or == "SINGLE RANGE":
        time_input = input("\n" + '''Enter your condition on time in exact format without brackets as [ {operator} '24HR:MIN:SEC' ]. 
        Use exactly the symbols: = , < , > , >= , <=
        Example: [ < '13:00:00' ]\n''' + "\n")
        time_choice = [time_input]
    else:
        time_choice = ''

############################################################################################################        
        
    if choice == "1":
        choice_and_or = input("\n" + '''Type 'AND' if you want to search for tweets containing all words. 
Type 'OR' if you want to search for tweets containing any of the words.
Type any key to search for one word or phrase.\n''' + "\n")
        
        if choice_and_or == "AND" or choice_and_or == "OR":
            words_input = input("\nEnter the words for which you'd like to search, separated by commas.\n")
            words = [word.strip() for word in words_input.split(',')]
        else:
            words_input = input("\nEnter the word or phrase for which you'd like to search.\n")
            words = words_input
        
            
        result = string_search(words, choice_and_or, date_and_or, range_choice, time_and_or, time_choice)
        
        if result.empty:
            print("\n" + "################################################")
            print("\n" + "No matching tweets. Please continue your search.")
            search()
        else:
            return result
            display(result)
            explore_request(result)
        

    if choice == "2":
        choice_and_or = input("\n" + '''Type 'AND' if you want to search for tweets containing all hashtags. 
Type 'OR' if you want to search for hashtags containing any of the hashtags.
Type any key to search for one hashtag.\n''' + "\n")
        
        if choice_and_or == "AND" or choice_and_or == "OR":
            hashtags_input = input("\nEnter the hashtags for which you'd like to search, separated by commas.\n")
            hashtags = [hashtag.strip() for hashtag in hashtags_input.split(',')]
        else:
            hashtags_input = input("\nEnter the hashtag for which you'd like to search.\n")
            hashtags = hashtags_input
        
            
        result = hashtag_search(hashtags, choice_and_or, date_and_or, range_choice, time_and_or, time_choice)
        
        if result.empty:
            print("\n" + "################################################")
            print("\n" + "No matching tweets. Please continue your search.")
            search()
        else:
            return result
            display(result)
            explore_request(result)


    if choice == "3":
        choice_and_or = input("\n" + '''Type 'AND' if you want to search for tweets by all conditions on retweets. 
Type 'OR' if you want to search for tweets by any condition on retweets.
Type any key to search for tweets with a single condition on retweets.\n''' + "\n")
        
        if choice_and_or == "AND" or choice_and_or == "OR":
            retweets_input = input("\n" + '''\nEnter the conditions on retweets for which you'd like to search.
        Separated by commas, use exactly the symbols: = , < , > , >= , <=
        Example: [ > 215, < 300 ]\n''' + "\n")
            retweets = [conditions.strip() for conditions in retweets_input.split(',')]
        else:
            retweets_input = input("\n" + '''\nEnter the condition on retweets for which you'd like to search.
        Use exactly the symbols: = , < , > , >= , <=
        Example: [ > 215 ]\n''' + "\n")
            retweets = retweets_input
        
            
        result = retweet_search(retweets, choice_and_or, date_and_or, range_choice, time_and_or, time_choice)
        
        if result.empty:
            print("\n" + "################################################")
            print("\n" + "No matching tweets. Please continue your search.")
            search()
        else:
            return result
            display(result)
            explore_request(result)

# %% [markdown]
# ## Explore feature

# %%
def explore_request(result):
    
    explore_confirm = input('''Would you like to explore tweets further? Input the number corresponding to your search.
    1 -> Find all retweeting users
    2 -> Find all author's tweets
    3 -> Show top 10 tweets by retweet
    4 -> RESTART
    ''')
    
    if explore_confirm == "1":
        clear_output(wait=True)
        explore_tweet_id = input("\n" + '''Enter the id_str_tweet of the tweet for which you'd like to find all retweeting users.''' + "\n")
        explore_retweeting_users(explore_tweet_id)
        
    if explore_confirm == "2":
        clear_output(wait=True)
        explore_user_id = input("\n" + '''Enter the id_str_user of the user for which you'd like to find all tweets.''' + "\n")
        explore_authors_tweets(explore_user_id)
    
    if explore_confirm == "3":
        clear_output(wait=True)
        display(result.head(10))
        explore_request(result.head(10))
    
    if explore_confirm == "4":
        clear_output(wait=True)
        search()

def explore_retweeting_users(tweet_id):
    
    sql_query = f"""
    SELECT 
        text, 
        retweet_count, 
        DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS date,
        TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS time,
        id_str_retweet_user,
        id_str_retweet
    FROM `msds-417117.Retweets.Retweets`
    WHERE id_str_tweet = '{tweet_id}'
    ORDER BY retweet_count DESC
    """

    query = client.query(sql_query)
    result = query.to_dataframe()

    if result.empty:
        clear_output(wait=True)
        print("\n" + "################################################")
        print("\n" + "No matching tweets. Please continue your search.")
        search()
    else:
        display(result)
        explore_request(result)
        return result


def explore_authors_tweets(user_id):
    
    sql_query = f"""
    SELECT 
        text, 
        retweet_count, 
        DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS date,
        TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS time,
        id_str_user,
        id_str_tweet
    FROM `msds-417117.Tweets.Tweets`
    WHERE id_str_user = '{user_id}'
    ORDER BY retweet_count DESC
    """

    query = client.query(sql_query)
    result = query.to_dataframe()
    
    if result.empty:
        clear_output(wait=True)
        print("\n" + "################################################")
        print("\n" + "No matching tweets. Please continue your search.")
        search()
    else:
        display(result)
        explore_request(result)
        return result

# %%
import heapq
import time
import pickle
from IPython.display import clear_output, display
from search_functions import SearchInMongoDB
from search_functions import SearchCache

# %%
# Create an instance of the cache
search_cache = SearchCache()
search_cache.load_cache("search_cache.pkl")

# %% [markdown]
# Search Function

# %%
def search():
    clear_output(wait=True)
    
    choice = input('''Which metric would you like to search? Input the number corresponding to your choice.
    1 -> Search by word in tweet
    2 -> Search by hashtag in tweet
    3 -> Search by number of retweets
    4 -> RESTART
    5 -> EXIT
    ''' + "\n")
    
    if choice == "5":
        print("Exiting the program.")
        return
    
    if choice == "4" or choice not in ("1", "2", "3"):
        search()
    
    date_and_or = input("\n" + '''Would you like to provide a date range to search? Type 'AND RANGE', 'OR RANGE', 'SINGLE RANGE', or 'NO'.
    ''' + "\n")
    
    if date_and_or == "AND RANGE" or date_and_or == "OR RANGE":
        range_input = input("\n" + '''Enter your conditions on date in exact format without brackets as [ {operator} 'YYYY-MM-DD' ]. 
        Separated by commas, use exactly the symbols: = , < , > , >= , <=
        Example: [ < '2020-04-25', > '2020-03-07' ]\n''' + "\n")
        range_choice = [condition.strip() for condition in range_input.split(',')]
    elif date_and_or == "SINGLE RANGE":
        range_input = input("\n" + '''Enter your condition on date in exact format without brackets as [ {operator} 'YYYY-MM-DD' ]. 
        Use exactly the symbols: = , < , > , >= , <=
        Example: [ < '2020-04-25' ]\n''' + "\n")
        range_choice = [range_input]
    else:
        range_choice = ''
        
    time_and_or = input("\n" + '''Would you like to provide a time range to search? Type 'AND RANGE', 'OR RANGE', 'SINGLE RANGE', or 'NO'.
    ''' + "\n")
        
    if time_and_or == "AND RANGE" or time_and_or == "OR RANGE":
        time_input = input("\n" + '''Enter your conditions on time in exact format without brackets as [ {operator} '24HR:MIN:SEC' ]. 
        Separated by commas, use exactly the symbols: = , < , > , >= , <=
        Example: [ < '13:00:00', > '12:40:00' ]\n''' + "\n")
        time_choice = [condition.strip() for condition in time_input.split(',')]
    elif time_and_or == "SINGLE RANGE":
        time_input = input("\n" + '''Enter your condition on time in exact format without brackets as [ {operator} '24HR:MIN:SEC' ]. 
        Use exactly the symbols: = , < , > , >= , <=
        Example: [ < '13:00:00' ]\n''' + "\n")
        time_choice = [time_input]
    else:
        time_choice = ''
        
    if choice == "1":
        choice_and_or = input("\n" + '''Type 'AND' if you want to search for tweets containing all words. 
Type 'OR' if you want to search for tweets containing any of the words.
Type any key to search for one word or phrase.\n''' + "\n")
        
        if choice_and_or == "AND" or choice_and_or == "OR":
            words_input = input("\nEnter the words for which you'd like to search, separated by commas.\n")
            words = [word.strip() for word in words_input.split(',')]
        else:
            words_input = input("\nEnter the word or phrase for which you'd like to search.\n")
            words = words_input
        
        # Check cache for search input
        cache_key = (words, choice_and_or, date_and_or, range_choice, time_and_or, time_choice)
        cached_result = search_cache.get_search_result(cache_key)
        
        if cached_result is not None:
            print("\n" + "################################################")
            print("\n" + "Returning result from cache:")
            display(cached_result)
            explore_request(cached_result)
            return
        
        result = string_search(words, choice_and_or, date_and_or, range_choice, time_and_or, time_choice)
        
        if result.empty:
            print("\n" + "################################################")
            print("\n" + "No matching tweets. Please continue your search.")
            search()
        else:
            search_cache.store_search(cache_key, result)
            display(result)
            explore_request(result)
        

    if choice == "2":
        choice_and_or = input("\n" + '''Type 'AND' if you want to search for tweets containing all hashtags. 
Type 'OR' if you want to search for hashtags containing any of the hashtags.
Type any key to search for one hashtag.\n''' + "\n")
        
        if choice_and_or == "AND" or choice_and_or == "OR":
            hashtags_input = input("\nEnter the hashtags for which you'd like to search, separated by commas.\n")
            hashtags = [hashtag.strip() for hashtag in hashtags_input.split(',')]
        else:
            hashtags_input = input("\nEnter the hashtag for which you'd like to search.\n")
            hashtags = hashtags_input
        
        # Check cache for search input
        cache_key = (hashtags, choice_and_or, date_and_or, range_choice, time_and_or, time_choice)
        cached_result = search_cache.get_search_result(cache_key)
        
        if cached_result is not None:
            print("\n" + "################################################")
            print("\n" + "Returning result from cache:")
            display(cached_result)
            explore_request(cached_result)
            return
        
        result = hashtag_search(hashtags, choice_and_or, date_and_or, range_choice, time_and_or, time_choice)
        
        if result.empty:
            print("\n" + "################################################")
            print("\n" + "No matching tweets. Please continue your search.")
            search()
        else:
            search_cache.store_search(cache_key, result)
            display(result)
            explore_request(result)


    if choice == "3":
        choice_and_or = input("\n" + '''Type 'AND' if you want to search for tweets by all conditions on retweets. 
Type 'OR' if you want to search for tweets by any condition on retweets.
Type any key to search for tweets with a single condition on retweets.\n''' + "\n")
        
        if choice_and_or == "AND" or choice_and_or == "OR":
            retweets_input = input("\n" + '''\nEnter the conditions on retweets for which you'd like to search.
        Separated by commas, use exactly the symbols: = , < , > , >= , <=
        Example: [ > 215, < 300 ]\n''' + "\n")
            retweets = [conditions.strip() for conditions in retweets_input.split(',')]
        else:
            retweets_input = input("\n" + '''\nEnter the condition on retweets for which you'd like to search.
        Use exactly the symbols: = , < , > , >= , <=
        Example: [ > 215 ]\n''' + "\n")
            retweets = retweets_input
        
        # Check cache for search input
        cache_key = (retweets, choice_and_or, date_and_or, range_choice, time_and_or, time_choice)
        cached_result = search_cache.get_search_result(cache_key)
        
        if cached_result is not None:
            print("\n" + "################################################")
            print("\n" + "Returning result from cache:")
            display(cached_result)
            explore_request(cached_result)
            return
        
        result = retweet_search(retweets, choice_and_or, date_and_or, range_choice, time_and_or, time_choice)
        
        if result.empty:
            print("\n" + "################################################")
            print("\n" + "No matching tweets. Please continue your search.")
            search()
        else:
            search_cache.store_search(cache_key, result)
            display(result)
            explore_request(result)

    # Save the cache after updating it
    search_cache.save_cache("search_cache.pkl")
    
    explore_request(result)

# %% [markdown]
# Explore Functions

# %%
def explore_request(result):
    
    explore_confirm = input('''Would you like to explore tweets further? Input the number corresponding to your search.
    1 -> Find all retweeting users
    2 -> Find all author's tweets
    3 -> Show top 10 tweets by retweet
    4 -> RESTART
    5 -> EXIT
    ''')
    
    if explore_confirm == "5":
        print("Exiting the program.")
        return
    
    if explore_confirm == "4":
        search()
    
    if explore_confirm == "1":
        clear_output(wait=True)
        explore_tweet_id = input("\n" + '''Enter the id_str_tweet of the tweet for which you'd like to find all retweeting users.''' + "\n")
        explore_retweeting_users(explore_tweet_id)
        
    if explore_confirm == "2":
        clear_output(wait=True)
        explore_user_id = input("\n" + '''Enter the id_str_user of the user for which you'd like to find all tweets.''' + "\n")
        explore_authors_tweets(explore_user_id)
    
    if explore_confirm == "3":
        clear_output(wait=True)
        display(result.head(10))
        explore_request(result.head(10))

def explore_retweeting_users(tweet_id):
    
    sql_query = f"""
    SELECT 
        text, 
        retweet_count, 
        DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS date,
        TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS time,
        id_str_retweet_user,
        id_str_retweet
    FROM `msds-417117.Retweets.Retweets`
    WHERE id_str_tweet = '{tweet_id}'
    ORDER BY retweet_count DESC
    """

    query = client.query(sql_query)
    result = query.to_dataframe()

    if result.empty:
        clear_output(wait=True)
        print("\n" + "################################################")
        print("\n" + "No matching tweets. Please continue your search.")
        search()
    else:
        display(result)
        explore_request(result)
        return result

# %%
def explore_authors_tweets(user_id):
    
    sql_query = f"""
    SELECT 
        text, 
        retweet_count, 
        DATE(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS date,
        TIME(PARSE_TIMESTAMP('%a %b %d %T %z %Y', created_at)) AS time,
        id_str_user,
        id_str_tweet
    FROM `msds-417117.Tweets.Tweets`
    WHERE id_str_user = '{user_id}'
    ORDER BY retweet_count DESC
    """

    query = client.query(sql_query)
    result = query.to_dataframe()
    
    if result.empty:
        clear_output(wait=True)
        print("\n" + "################################################")
        print("\n" + "No matching tweets. Please continue your search.")
        search()
    else:
        display(result)
        explore_request(result)
        return result

# %% [markdown]
# Running  the cache and saving

# %%
# Call the search function to start searching
search()
search_cache.save_cache("search_cache.pkl")
# Out:
# ################################################
#
# Returning result from cache:
#                                                 text  retweet_count  \
# 0  Abi ooooo na fault #Roksie as Liverpool top EP...              2
# 1  @RoyalANfield Remember when people were saying...              0
# 2  Look at how Liverpool bossed my season. Corona...              0
# 3   @LFCVine Corona virus is holding Liverpool title              0
# 4  #2020WasFunUntil I thought Liverpool will win ...              0
# 5  Ei so enobi corona like Liverpool really win t...              0
# 6   Omo, Liverpool fans no fit lie on top Corona now              0
# 7  @RahmanVanny @Amiftachul @Bagus_Adetya Curhat ...              0
# 8  @panditfootball Liverpool fans said : Terima k...              0
# 9  Wali Kota Liverpool Duga Fans Atletico Ikut Ba...              0
#
#          date      time          id_str_user         id_str_tweet
# 0  2020-04-25  13:21:01  1159503198929006595  1254037702737084418
# 1  2020-04-25  12:30:21  1206331733521653767  1254024948949147648
# 2  2020-04-25  13:42:20   702920800450584578  1254043066761129984
# 3  2020-04-25  13:55:47            335928126  1254046451648299010
# 4  2020-04-25  14:00:03           2155108424  1254047524962349057
# 5  2020-04-25  14:11:41            361425581  1254050450032263172
# 6  2020-04-25  14:43:26            103603653  1254058440630075393
# 7  2020-04-25  12:25:35             89914690  1254023750590164992
# 8  2020-04-25  13:48:48            181158916  1254044695107301376
# 9  2020-04-25  13:51:06             47596019  1254045269995352065

# %%
#CODE TO DISPLAY CACHE WITHOUT THE .PKL FILE

# def display_cache():
#     current_cache = search_cache.cache
#     if not current_cache:
#         print("Current Cache is Empty!")
#     else:
#         print("Current Cache:")
#         for key, value in current_cache.items():
#             print(f"Search Input: {key} => Search Result: {value}")

# # Call this function to display the current cache
# display_cache()

# %%
#RUN THIS TO VIEW THE CONTENTS OF CACHE IN THE .PKL FILE

cache_filename = "search_cache.pkl"

def display_cache(filename):
    try:
        # Load the cache from the file
        with open(filename, "rb") as f:
            cache = pickle.load(f)
        if not cache:
            print("Cache file is empty.") 
        else:
        # Display each key-value pair in the cache
            for key, value in cache.items():
                print(f"Key: {key}\nValue: {value}\n")
            
    except FileNotFoundError:
        print(f"Cache file '{filename}' not found.")

# %%
# Call the function to display the cache
display_cache(cache_filename)
# Out:
# Key: ('Corona', 'N', 'ni', '', 'NO', '')
# Value:                                                    text  retweet_count  \
# 0     If that’s how they are following lockdown/soci...            422
# 1     Once the Corona Crisis are over, I am not goin...            158
# 2     Mereka itu yg menyebarkan Corona di Indonesia ...            130
# 3     After China, Japan wants to use Pakistan for H...            112
# 4     Bukan Corona Tapi Kelaparan, Seorang Tukang Be...             66
# ...                                                 ...            ...
# 5997  Coronavirus Haryana Case Live | Corona Cases L...              0
# 5998  VIDEO : Ratnagiri Corona Breaking | रत्नागिरी ...              0
# 5999  @ashokgehlot51 Corona pe bat karo cm sahab ji ...              0
# 6000  जहां IPL का score देखना था \nवहां Corona का Sc...              0
# 6001  Magufuli:  asamehe wafungwa 3,973 , atoa ujumb...              0
#
#             date      time          id_str_user         id_str_tweet
# 0     2020-04-25  13:25:32   769108935726997504  1254038838403493889
# 1     2020-04-25  14:07:17  1208374768769986560  1254049344610680838
# 2     2020-04-25  13:48:12            114697372  1254044541893500932
# 3     2020-04-25  13:46:38           1095295038  1254044146916044802
# 4     2020-04-25  13:52:23  1082992095361609728  1254045596266098695
# ...          ...       ...                  ...                  ...
# 5997  2020-04-25  14:30:08           3972033373  1254055093290369031
# 5998  2020-04-25  14:36:46           3360174258  1254056762983903233
# 5999  2020-04-25  14:41:20   792403496825974786  1254057911573254144
# 6000  2020-04-25  14:47:04           3198804318  1254059355084918787
# 6001  2020-04-25  14:48:08   949434683028398080  1254059624715739137
#
# [6002 rows x 6 columns]
#
# Key: ('Covid', 'b', 'no', '', 'no', '')
# Value:                                                  text  retweet_count  \
# 0   Today 9 pm: doctors from across South Asia com...             35
# 1   New : Kerala reports 7 New Cases of Corona Vir...              8
# 2   A spotlight and magnifying glass needs to be u...              5
# 3   @drgdpuri Our young corona warriors after fini...              2
# 4   No Covid Rapid Tests since last 72 hours due t...              2
# 5   A Mira, sua madre è stata portata via dal Covi...              2
# 6   Yes! Resistance to the Covid Corona Lies! CALI...              1
# 7   A young journalist tests positive for Corona v...              1
# 8   Karimnagar was the 1st city in Telangana which...              1
# 9   @ItsAMettWorld Zum Glück wird Covid 19 nicht d...              0
# 10  @AymFulln @gizmo97750411 @ladyhawkerfinds @mor...              0
# 11  @Jordan_Sather_ Have they ever had a successfu...              0
# 12  @MelissaJPeltier I love Dr. Dena!! She is a le...              0
# 13  Can somebody help me find Corona nickname Rona...              0
# 14  People be protesting having to stay inside, br...              0
# 15  @sardanarohit @aajtak They should be compulsor...              0
# 16  Haemo UV Light treatment similar to Haemo Lase...              0
# 17  @Kissht_EMI Covid 19 corona for extent my loan...              0
# 18      @morganapple I've seen Covid and Corona twins              0
# 19  We are saying Covid 19, yes Covid 19 is real, ...              0
# 20  16 Person Tested Positive For Corona On Saturd...              0
# 21  Watch our Special Programme on Covid 19 "Coron...              0
# 22  Imagine if the media reported on homelessness ...              0
# 23  Corona Covid 19 10pcs KN95 Cycling Face Mask S...              0
# 24  As of April 23rd #Howrah district has Total Co...              0
# 25  @crpfindia Covid Poster Challenge. Drawing by ...              0
# 26  Se servir des soignants et de travailleurs dés...              0
# 27  @JM_Lafon 1ère victime du corona 19 c'est son ...              0
# 28  @ChouhanShivraj Covid 19 से किसी पुलिस का निधन...              0
# 29  Artis Dadakan di musim Virus Corona Covid 19 A...              0
# 30  KNPI Klungkung Gandeng Lingkar Sehat Bali pedu...              0
# 31  Muncul Manusia Tolol ⁦@rockygerung_rg⁩ cara pe...              0
# 32  Artis Dadakan di musim Virus Corona Covid 19, ...              0
# 33  Personel Polsek Krueng Raya melaksanakan Himba...              0
# 34  Personel Polsek Krueng Raya melaksanakan Himba...              0
# 35  Personel Polsek Krueng Raya melaksanakan Himba...              0
# 36  Apa beda Corona dengan Covid 19...\nApa beda T...              0
# 37  Data Terbaru Data Per Provinsi Covid 19 Virus ...              0
# 38  Tim Gugus Tugas Penanggulangan Covid 19 Kabupa...              0
# 39  Pemasangan Spanduk "Pasar Rakyat Aman dari Cov...              0
# 40  @Cartabellotta Ma se il Covid 19 è un virus in...              0
# 41  Coronavirus, calano i contagi: a Eboli chiude ...              0
# 42  Dit verbaast mij, iemand die op 4 april Covid ...              0
# 43  Mumuzinho pegou Covid pqp, largue ele agoraaaa...              0
# 44  April 25, 2020. Rev Tony Evans Corona Virus Co...              0
#
#           date      time          id_str_user         id_str_tweet
# 0   2020-04-25  12:29:54             56304605  1254024835535122433
# 1   2020-04-25  13:00:02            168976061  1254032422359846912
# 2   2020-04-25  13:17:00   710489142996631552  1254036690076864512
# 3   2020-04-25  13:01:25           2588238835  1254032768033423361
# 4   2020-04-25  13:47:32  1251903714052489218  1254044375362883585
# 5   2020-04-25  14:00:00            215728045  1254047513591439360
# 6   2020-04-25  13:09:57   982246248294920193  1254034914737106944
# 7   2020-04-25  13:46:03           2791170116  1254044002451550214
# 8   2020-04-25  14:41:17            334550003  1254057901364113409
# 9   2020-04-25  13:02:42  1203036169925222408  1254033090797801473
# 10  2020-04-25  12:24:25  1242615819143647235  1254023457471422465
# 11  2020-04-25  12:57:33             34759202  1254031794292342792
# 12  2020-04-25  13:03:50           4269030077  1254033374844456962
# 13  2020-04-25  13:11:16  1226744811526512641  1254035248356212739
# 14  2020-04-25  13:21:55           1328292594  1254037926498861056
# 15  2020-04-25  13:22:07           1356300410  1254037976117415936
# 16  2020-04-25  13:33:06           1608180763  1254040742768439297
# 17  2020-04-25  13:35:53  1253960843449913345  1254041441531162625
# 18  2020-04-25  13:37:00             50089375  1254041724944551937
# 19  2020-04-25  13:37:55           1884557143  1254041953790025728
# 20  2020-04-25  13:40:02  1229800127335981056  1254042486525304838
# 21  2020-04-25  13:45:00   738961985488834561  1254043735723094019
# 22  2020-04-25  13:48:17  1040233608026497026  1254044563834130433
# 23  2020-04-25  13:50:58  1076044678116638720  1254045239637168131
# 24  2020-04-25  14:10:48            108234543  1254050230191833091
# 25  2020-04-25  14:14:43             76290171  1254051213622083585
# 26  2020-04-25  12:55:42   870257757055799298  1254031328674295810
# 27  2020-04-25  13:39:18  1242412793028018176  1254042301216718849
# 28  2020-04-25  13:05:55  1171361680757886976  1254033902286417921
# 29  2020-04-25  12:52:48            449735911  1254030601667186688
# 30  2020-04-25  12:53:31   798478258119405568  1254030781565018112
# 31  2020-04-25  12:55:01   925295869728997377  1254031157399678976
# 32  2020-04-25  13:00:21            449735911  1254032502236368897
# 33  2020-04-25  13:16:06  1247129549411733506  1254036464444125185
# 34  2020-04-25  13:16:25  1247129549411733506  1254036545486548995
# 35  2020-04-25  13:16:48  1247129549411733506  1254036639606730754
# 36  2020-04-25  13:32:36   874202239958568964  1254040616536690688
# 37  2020-04-25  13:33:47           1325064613  1254040911992020993
# 38  2020-04-25  13:44:59           3931215560  1254043732644683777
# 39  2020-04-25  14:00:12  1106415251589758976  1254047559850446849
# 40  2020-04-25  13:27:20   731889024630161409  1254039288691523590
# 41  2020-04-25  13:48:07           2282351922  1254044522016800768
# 42  2020-04-25  14:30:09            425246410  1254055099401490435
# 43  2020-04-25  14:03:15            436141009  1254048330646269962
# 44  2020-04-25  14:15:06             16836098  1254051310875422727
#
# Key: ('Lockdown', 'n', 'NO', '', 'NO', '')
# Value:                                                  text  retweet_count  \
# 0   Why is Lockdown Important ? \nHow is Corona Vi...              3
# 1   RKI-Corona-Studie: Lockdown hat kaum Einfluss ...              2
# 2   🎧@ClassiQDjFAZE🎚️\n#NowPlayingOnStarFM\n\n#NP ...              1
# 3   Number of Corona Patient are drastically incre...              1
# 4   An Actor, Something Interesting about me and M...              1
# ..                                                ...            ...
# 57  #bankersunited #Bankers\n\nBankers Anthem | Lo...              0
# 58  @RajatSharmaLive @indiatvnews Lockdown ka pala...              0
# 59  Corona Virus और Lockdown का एक अच्छा असर, Vara...              0
# 60  Coronavirus In India Live Updates News In Hind...              0
# 61  @PMOIndia @HMOIndia मान्यवर 3 मई के बाद Lockdo...              0
#
#           date      time          id_str_user         id_str_tweet
# 0   2020-04-25  14:38:32             14568290  1254057210272862210
# 1   2020-04-25  13:46:49  1131226011692077058  1254044193351229442
# 2   2020-04-25  12:27:49           1278541345  1254024314178936832
# 3   2020-04-25  12:49:37  1101499219838468103  1254029797187039233
# 4   2020-04-25  14:10:50             72566747  1254050237456539649
# ..         ...       ...                  ...                  ...
# 57  2020-04-25  14:40:32             60854598  1254057710678675457
# 58  2020-04-25  14:43:01  1254056440592871425  1254058338284826625
# 59  2020-04-25  12:38:32            155171363  1254027008633442305
# 60  2020-04-25  13:09:32            549814014  1254034811984982018
# 61  2020-04-25  13:36:59            136916951  1254041718774812673
#
# [62 rows x 6 columns]
#
# Key: ('Vaccine', 'N', 'NO', '', 'NO', '')
# Value:                                                 text  retweet_count  \
# 0  Corona Vaccine Design Earns Israeli Scientist ...              0
# 1  When will a Vaccine be found for #coronavirus ...              0
# 2  @klrahul11 Bhai Corona ki Vaccine dhund lo yr....              0
# 3  💊💉💊💉💊💉💊💉💊💉💊💉\n*Corona ki Vaccine bana nay mein...              0
# 4  Corona Vaccine Ka Tajurba Bandaron (Monkey) Pr...              0
#
#          date      time          id_str_user         id_str_tweet
# 0  2020-04-25  12:55:43            493356188  1254031336257568769
# 1  2020-04-25  13:36:20  1254017007533449222  1254041554764914688
# 2  2020-04-25  13:42:23           2506772864  1254043077792104449
# 3  2020-04-25  14:36:33  1208921617763430401  1254056710047596544
# 4  2020-04-25  12:26:16            635137913  1254023924314185735
#
# Key: ('Trump', 'M', 'NO', '', 'NO', '')
# Value:                                                   text  retweet_count  \
# 0    Ein deutscher Arzt behauptet es gäbe ganz einf...             14
# 1    #VenceremosAlCovid19 corona Trump y sus estupi...             11
# 2    @JeffreyGuterman @realDonaldTrump @TripleH Tru...              7
# 3    Little known medical fact: Trump is immune to ...              7
# 4    Marx referred to Hegel to say: all major thing...              6
# ..                                                 ...            ...
# 316  O Trump sugerindo aos americanos tomar desinfe...              0
# 317  @ClimateCollapse Favoriten var att han kritise...              0
# 318             @ShilpiSinghINC Trump aaya Corona laya              0
# 319  Neyse deterjan icme ye ne dersiniz raki varken...              0
# 320  birlikte katlandı.\n\nGecen gun Trump dedi ki,...              0
#
#            date      time          id_str_user         id_str_tweet
# 0    2020-04-25  12:45:46  1074705012847194119  1254028830039330816
# 1    2020-04-25  13:31:13            141940558  1254040269424668672
# 2    2020-04-25  12:22:21  1217267259485360134  1254022936824070146
# 3    2020-04-25  13:57:07            238220689  1254046783971434496
# 4    2020-04-25  13:09:42             43079989  1254034851910606848
# ..          ...       ...                  ...                  ...
# 316  2020-04-25  14:16:10  1044195142620590080  1254051580321697793
# 317  2020-04-25  13:01:09             27603397  1254032701268639744
# 318  2020-04-25  14:35:23   844224269605392386  1254056418057084930
# 319  2020-04-25  12:58:14   708716950877241344  1254031967550570497
# 320  2020-04-25  14:07:14  1187836930781786113  1254049332866830336
#
# [321 rows x 6 columns]
#
# Key: ('Corona', 'n', 'no', '', 'no', '')
# Value:                                                    text  retweet_count  \
# 0     If that’s how they are following lockdown/soci...            422
# 1     Once the Corona Crisis are over, I am not goin...            158
# 2     Mereka itu yg menyebarkan Corona di Indonesia ...            130
# 3     After China, Japan wants to use Pakistan for H...            112
# 4     Bukan Corona Tapi Kelaparan, Seorang Tukang Be...             66
# ...                                                 ...            ...
# 5997  Coronavirus Haryana Case Live | Corona Cases L...              0
# 5998  VIDEO : Ratnagiri Corona Breaking | रत्नागिरी ...              0
# 5999  @ashokgehlot51 Corona pe bat karo cm sahab ji ...              0
# 6000  जहां IPL का score देखना था \nवहां Corona का Sc...              0
# 6001  Magufuli:  asamehe wafungwa 3,973 , atoa ujumb...              0
#
#             date      time          id_str_user         id_str_tweet
# 0     2020-04-25  13:25:32   769108935726997504  1254038838403493889
# 1     2020-04-25  14:07:17  1208374768769986560  1254049344610680838
# 2     2020-04-25  13:48:12            114697372  1254044541893500932
# 3     2020-04-25  13:46:38           1095295038  1254044146916044802
# 4     2020-04-25  13:52:23  1082992095361609728  1254045596266098695
# ...          ...       ...                  ...                  ...
# 5997  2020-04-25  14:30:08           3972033373  1254055093290369031
# 5998  2020-04-25  14:36:46           3360174258  1254056762983903233
# 5999  2020-04-25  14:41:20   792403496825974786  1254057911573254144
# 6000  2020-04-25  14:47:04           3198804318  1254059355084918787
# 6001  2020-04-25  14:48:08   949434683028398080  1254059624715739137
#
# [6002 rows x 6 columns]
#
# Key: ('Liverpool', 'n', 'no', '', 'no', '')
# Value:                                                 text  retweet_count  \
# 0  Abi ooooo na fault #Roksie as Liverpool top EP...              2
# 1  @RoyalANfield Remember when people were saying...              0
# 2  Look at how Liverpool bossed my season. Corona...              0
# 3   @LFCVine Corona virus is holding Liverpool title              0
# 4  #2020WasFunUntil I thought Liverpool will win ...              0
# 5  Ei so enobi corona like Liverpool really win t...              0
# 6   Omo, Liverpool fans no fit lie on top Corona now              0
# 7  @RahmanVanny @Amiftachul @Bagus_Adetya Curhat ...              0
# 8  @panditfootball Liverpool fans said : Terima k...              0
# 9  Wali Kota Liverpool Duga Fans Atletico Ikut Ba...              0
#
#          date      time          id_str_user         id_str_tweet
# 0  2020-04-25  13:21:01  1159503198929006595  1254037702737084418
# 1  2020-04-25  12:30:21  1206331733521653767  1254024948949147648
# 2  2020-04-25  13:42:20   702920800450584578  1254043066761129984
# 3  2020-04-25  13:55:47            335928126  1254046451648299010
# 4  2020-04-25  14:00:03           2155108424  1254047524962349057
# 5  2020-04-25  14:11:41            361425581  1254050450032263172
# 6  2020-04-25  14:43:26            103603653  1254058440630075393
# 7  2020-04-25  12:25:35             89914690  1254023750590164992
# 8  2020-04-25  13:48:48            181158916  1254044695107301376
# 9  2020-04-25  13:51:06             47596019  1254045269995352065
#
# Key: ('Corona', 'N', 'NO', '', 'NO', '')
# Value:                                                    text  retweet_count  \
# 0     If that’s how they are following lockdown/soci...            422
# 1     Once the Corona Crisis are over, I am not goin...            158
# 2     Mereka itu yg menyebarkan Corona di Indonesia ...            130
# 3     After China, Japan wants to use Pakistan for H...            112
# 4     Bukan Corona Tapi Kelaparan, Seorang Tukang Be...             66
# ...                                                 ...            ...
# 5997  Coronavirus Haryana Case Live | Corona Cases L...              0
# 5998  VIDEO : Ratnagiri Corona Breaking | रत्नागिरी ...              0
# 5999  @ashokgehlot51 Corona pe bat karo cm sahab ji ...              0
# 6000  जहां IPL का score देखना था \nवहां Corona का Sc...              0
# 6001  Magufuli:  asamehe wafungwa 3,973 , atoa ujumb...              0
#
#             date      time          id_str_user         id_str_tweet
# 0     2020-04-25  13:25:32   769108935726997504  1254038838403493889
# 1     2020-04-25  14:07:17  1208374768769986560  1254049344610680838
# 2     2020-04-25  13:48:12            114697372  1254044541893500932
# 3     2020-04-25  13:46:38           1095295038  1254044146916044802
# 4     2020-04-25  13:52:23  1082992095361609728  1254045596266098695
# ...          ...       ...                  ...                  ...
# 5997  2020-04-25  14:30:08           3972033373  1254055093290369031
# 5998  2020-04-25  14:36:46           3360174258  1254056762983903233
# 5999  2020-04-25  14:41:20   792403496825974786  1254057911573254144
# 6000  2020-04-25  14:47:04           3198804318  1254059355084918787
# 6001  2020-04-25  14:48:08   949434683028398080  1254059624715739137
#
# [6002 rows x 6 columns]
#
# Key: ('Liverpool', 'N', 'NO', '', 'NO', '')
# Value:                                                 text  retweet_count  \
# 0  Abi ooooo na fault #Roksie as Liverpool top EP...              2
# 1  @RoyalANfield Remember when people were saying...              0
# 2  Look at how Liverpool bossed my season. Corona...              0
# 3   @LFCVine Corona virus is holding Liverpool title              0
# 4  #2020WasFunUntil I thought Liverpool will win ...              0
# 5  Ei so enobi corona like Liverpool really win t...              0
# 6   Omo, Liverpool fans no fit lie on top Corona now              0
# 7  @RahmanVanny @Amiftachul @Bagus_Adetya Curhat ...              0
# 8  @panditfootball Liverpool fans said : Terima k...              0
# 9  Wali Kota Liverpool Duga Fans Atletico Ikut Ba...              0
#
#          date      time          id_str_user         id_str_tweet
# 0  2020-04-25  13:21:01  1159503198929006595  1254037702737084418
# 1  2020-04-25  12:30:21  1206331733521653767  1254024948949147648
# 2  2020-04-25  13:42:20   702920800450584578  1254043066761129984
# 3  2020-04-25  13:55:47            335928126  1254046451648299010
# 4  2020-04-25  14:00:03           2155108424  1254047524962349057
# 5  2020-04-25  14:11:41            361425581  1254050450032263172
# 6  2020-04-25  14:43:26            103603653  1254058440630075393
# 7  2020-04-25  12:25:35             89914690  1254023750590164992
# 8  2020-04-25  13:48:48            181158916  1254044695107301376
# 9  2020-04-25  13:51:06             47596019  1254045269995352065

# %%
#CODE TO CREATE THE EMPTY .PKL FILE IN YOUR LAPTOP

# import pickle

# def create_empty_file(file_path):
#     # Create an empty dictionary to store in the file
#     empty_data = {}

#     # Open the file in write mode, which will create the file if it doesn't exist
#     with open(file_path, 'wb') as file:
#         # Pickle the empty dictionary and write it to the file
#         pickle.dump(empty_data, file)

#     print(f"Empty file 'search_cache.pkl' created at: {file_path}")

# # Specify the location where you want to create the file
# file_location = "/Users/divyashah/Downloads/Twitter project/search_cache.pkl"

# # Call the function with the specified location
# create_empty_file(file_location)
# Out:
# Empty file 'search_cache.pkl' created at: /Users/divyashah/Downloads/Twitter project/search_cache.pkl

# %%
#CODE TO CLEAR ENTIRE CACHE WHEN NEEDED

# import pickle
# pickle_file = "/Users/divyashah/Downloads/Twitter project/search_cache.pkl"
# with open(pickle_file, "wb") as file:
#     empty_object = {}
#     pickle.dump(empty_object, file)
# print("Contents of the pickle file cleared successfully.")
# Out:
# Contents of the pickle file cleared successfully.
